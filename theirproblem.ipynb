# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
os.chdir('/Users/linamolla/Desktop/DataBlog')

# %%
os.getcwd()
# Out:
# '/Users/linamolla/Desktop/DataBlog'

# %%
md = pd.read_csv('marriage.csv')
pd.set_option('display.max_columns', None)
md.head()
# Out:
#        Country  ISO code       Period  Year    Sex Non-standard age groups  \
# 0  Afghanistan         4  Around 1970  1973    Men                     NaN
# 1  Afghanistan         4  Around 1970  1973  Women                     NaN
# 2  Afghanistan         4           ..  1979    Men                     NaN
# 3  Afghanistan         4           ..  1979  Women                     NaN
# 4  Afghanistan         4  Around 2005  2008    Men                       x
#
#    15-19  20-24  25-29  30-34  35-39  40-44  45-49  50-54  55-59  60-64   65+  \
# 0    7.6   31.9   59.1   78.9   87.2   89.7   90.7   91.5   91.5   85.4  78.3
# 1   49.7   87.0   94.3   94.2   93.4   84.8   79.4   62.4   54.9   40.7  23.9
# 2    9.1   36.1   64.1   82.0   88.9   91.5   92.9   91.8   90.7   87.6  79.7
# 3   53.4   89.8   95.7   95.8   94.5   89.2   84.1   74.6   66.1   48.5  29.4
# 4   14.0    NaN   88.0    NaN    NaN   96.0    NaN    NaN    NaN    NaN  82.0
#
# ...

# %%
mdUSA = md[(md.Country == 'United States of America') & (md.Year >= 1980)]
mdUSA
# Out:
#                        Country  ISO code       Period  Year    Sex  \
# 1636  United States of America       840  Around 1985  1980    Men
# 1637  United States of America       840  Around 1985  1980  Women
# 1638  United States of America       840  Around 1995  1990    Men
# 1639  United States of America       840  Around 1995  1990  Women
# 1640  United States of America       840  Around 2005  2000    Men
# 1641  United States of America       840  Around 2005  2000  Women
# 1642  United States of America       840       Latest  2009    Men
# 1643  United States of America       840       Latest  2009  Women
#
#      Non-standard age groups  15-19  20-24  25-29  30-34  35-39  40-44  45-49  \
# 1636                     NaN    2.7   27.9   57.6   72.6   76.9   83.7   82.1
# 1637                     NaN    8.2   41.4   64.3   72.6   74.5   77.3   76.8
# 1638                       x    2.0   18.6   46.0   61.8   71.1    NaN   77.4
# ...

# %%
mdUSA[mdUSA.columns[list(range(6, 17))]]
# Out:
#       15-19  20-24  25-29  30-34  35-39  40-44  45-49  50-54  55-59  60-64  \
# 1636    2.7   27.9   57.6   72.6   76.9   83.7   82.1   82.6   83.2   82.9
# 1637    8.2   41.4   64.3   72.6   74.5   77.3   76.8   73.6   70.6   63.4
# 1638    2.0   18.6   46.0   61.8   71.1    NaN   77.4    NaN   80.2   80.2
# 1639    4.9   29.9   55.9   65.6   69.1    NaN   70.2    NaN   68.7   63.9
# 1640    3.8   18.9   44.1   59.8   67.1    NaN   72.2    NaN   76.2   78.0
# 1641    5.2   26.7   52.0   63.7   67.0    NaN   67.1    NaN   65.8   62.9
# 1642    0.8   11.0   34.1   56.6   65.2   66.1   65.6   69.3   74.0    NaN
# 1643    1.7   18.8   45.5   61.9   67.0   67.5   65.6   65.4   65.2    NaN
#
#        65+
# 1636  74.4
# 1637  36.3
# 1638  74.8
# 1639  38.6
# 1640  73.8
# 1641  41.9
# 1642  73.2
# 1643  43.0

# %%
mdUSA[mdUSA.columns[list(range(6, 17))]].mean(axis = 1)
# Out:
# 1636    66.054545
# 1637    59.909091
# 1638    56.900000
# 1639    51.866667
# 1640    54.877778
# 1641    50.255556
# 1642    51.590000
# 1643    50.160000
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
year to age in year
ax.plot(a, mdUSA[mdUSA.columns[list(range(6, 17))]].mean(axis = 1));

# %%
import plotly.express as px
import seaborn as sns

# %%
# mdplot = px.line(mdUSA, )

# %%
import pandas as pd

# %%
agedata = pd.read_excel('UNPD_WMD_2019_MARITAL_STATUS.xlsx', sheet_name = 'MARITAL_STATUS_BY_AGE')

# %%
new_header = agedata.iloc[0] #grab the first row for the header
agedata = agedata[1:] #take the data less the header row
agedata.columns = new_header #set the header row as the df header
agedata.head()
# Out:
# 1           df ISO code YearStart YearEnd  Sex MaritalStatus  \
# 2  Afghanistan        4      1972    1974  Men      Divorced
# 3  Afghanistan        4      1972    1974  Men      Divorced
# 4  Afghanistan        4      1972    1974  Men      Divorced
# 5  Afghanistan        4      1972    1974  Men      Divorced
# 6  Afghanistan        4      1972    1974  Men      Divorced
#
# 1 Non-standard_AgeGroups Series_contains_Non-standard_AgeGroups AgeGroup  \
# 2                    NaN                                    NaN  [15-19]
# 3                    NaN                                    NaN  [20-24]
# 4                    NaN                                    NaN  [25-29]
# 5                    NaN                                    NaN  [30-34]
# 6                    NaN                                    NaN  [35-39]
#
# 1 AgeStart AgeEnd DataValue DataProcess DataCatalog ShortName DataCatalog ID  \
# 2       15     19         0      Survey       1972-1974 NDFGS            160
# ...

# %%
ageUSA = agedata[agedata.df == 'United States of America']

# %%
ageUSA.head()
# Out:
# 1                             df ISO code YearStart YearEnd  Sex  \
# 258082  United States of America      840      1970    1970  Men
# 258083  United States of America      840      1970    1970  Men
# 258084  United States of America      840      1970    1970  Men
# 258085  United States of America      840      1970    1970  Men
# 258086  United States of America      840      1970    1970  Men
#
# 1      MaritalStatus Non-standard_AgeGroups  \
# 258082      Divorced                    NaN
# 258083      Divorced                    NaN
# 258084      Divorced                    NaN
# 258085      Divorced                    NaN
# 258086      Divorced                    NaN
#
# 1      Series_contains_Non-standard_AgeGroups AgeGroup AgeStart AgeEnd  \
# 258082                                    NaN  [10-14]       10     14
# 258083                                    NaN  [15-19]       15     19
# 258084                                    NaN  [20-24]       20     24
# ...

# %%
import matplotlib.pyplot as plt

# %%
#fig, ax = plt.subplots()
plt.bar(agedata.df[(agedata.df == 'United States of America') | (agedata.df == 'Canada')], agedata.AgeStart.mean())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-58cacdc6b35a> in <module>
#       1 #fig, ax = plt.subplots()
# ----> 2 plt.bar(agedata.df[(agedata.df == 'United States of America') | (agedata.df == 'Canada')], agedata.AgeStart.mean())
#       3 plt.show()
#
# NameError: name 'agedata' is not defined

# %% [markdown]
# ## Estimated Median Age At First Marriage in the US Visualization

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
os.getcwd()
os.chdir('/Users/linamolla/Desktop/DataBlog')
median_age = pd.read_excel('ms2.xls', sheet_name = 'Formatted_MS-2', header = 2, index_col = 0)
#new_header = median_age.iloc[7] #grab the first row for the header
#agedata = median_age[9:] #take the data less the header row
#median_age.columns = new_header #set the header row as the df header
median_age
# Out:
#        Men  Women
# 2021  30.4   28.6
# 2020  30.5   28.1
# 2019  29.8   28.0
# 2018  29.8   27.8
# 2017  29.5   27.4
# ...    ...    ...
# 1930  24.3   21.3
# 1920  24.6   21.2
# 1910  25.1   21.6
# 1900  25.9   21.9
# 1890  26.1   22.0
#
# [82 rows x 2 columns]

# %%
recent = median_age.iloc[0:43]
recent
# Out:
#        Men  Women
# 2021  30.4   28.6
# 2020  30.5   28.1
# 2019  29.8   28.0
# 2018  29.8   27.8
# 2017  29.5   27.4
# 2016  29.5   27.4
# 2015  29.2   27.1
# 2014  29.3   27.0
# 2013  29.0   26.6
# 2012  28.6   26.6
# 2011  28.4   26.4
# 2011  28.7   26.5
# 2010  28.2   26.1
# 2009  28.1   25.9
# 2008  27.6   25.9
# 2007  27.5   25.6
# 2006  27.5   25.5
# 2005  27.1   25.3
# 2004  27.4   25.3
# 2003  27.1   25.3
# 2002  26.9   25.3
# 2001  26.9   25.1
# 2000  26.8   25.1
# 1999  26.9   25.1
# 1998  26.7   25.0
# 1997  26.8   25.0
# 1996  27.1   24.8
# 1995  26.9   24.5
# 1994  26.7   24.5
# 1993  26.5   24.5
# 1992  26.5   24.4
# 1991  26.3   24.1
# 1990  26.1   23.9
# 1989  26.2   23.8
# 1988  25.9   23.6
# 1987  25.8   23.6
# 1986  25.7   23.1
# 1985  25.5   23.3
# 1984  25.4   23.0
# 1983  25.4   22.8
# 1982  25.2   22.5
# 1981  24.8   22.3
# 1980  24.7   22.0

# %%
recent.plot(color = ['blue', 'red'], xlabel = 'Year', ylabel = 'Median Age', 
            title = 'US Estimated Median Age at First Marriage:\n1980 to 2021');
