# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
os.getcwd()
os.chdir('/Users/linamolla/Desktop/DataBlog')
median_age = pd.read_excel('ms2.xls', sheet_name = 'Formatted_MS-2', header = 2, index_col = 0)
#new_header = median_age.iloc[7] #grab the first row for the header
#agedata = median_age[9:] #take the data less the header row
#median_age.columns = new_header #set the header row as the df header
median_age
# Out:
#        Men  Women
# 2021  30.4   28.6
# 2020  30.5   28.1
# 2019  29.8   28.0
# 2018  29.8   27.8
# 2017  29.5   27.4
# ...    ...    ...
# 1930  24.3   21.3
# 1920  24.6   21.2
# 1910  25.1   21.6
# 1900  25.9   21.9
# 1890  26.1   22.0
#
# [82 rows x 2 columns]

# %%
recent = median_age.iloc[0:43]
recent
# Out:
#        Men  Women
# 2021  30.4   28.6
# 2020  30.5   28.1
# 2019  29.8   28.0
# 2018  29.8   27.8
# 2017  29.5   27.4
# 2016  29.5   27.4
# 2015  29.2   27.1
# 2014  29.3   27.0
# 2013  29.0   26.6
# 2012  28.6   26.6
# 2011  28.4   26.4
# 2011  28.7   26.5
# 2010  28.2   26.1
# 2009  28.1   25.9
# 2008  27.6   25.9
# 2007  27.5   25.6
# 2006  27.5   25.5
# 2005  27.1   25.3
# 2004  27.4   25.3
# 2003  27.1   25.3
# 2002  26.9   25.3
# 2001  26.9   25.1
# 2000  26.8   25.1
# 1999  26.9   25.1
# 1998  26.7   25.0
# 1997  26.8   25.0
# 1996  27.1   24.8
# 1995  26.9   24.5
# 1994  26.7   24.5
# 1993  26.5   24.5
# 1992  26.5   24.4
# 1991  26.3   24.1
# 1990  26.1   23.9
# 1989  26.2   23.8
# 1988  25.9   23.6
# 1987  25.8   23.6
# 1986  25.7   23.1
# 1985  25.5   23.3
# 1984  25.4   23.0
# 1983  25.4   22.8
# 1982  25.2   22.5
# 1981  24.8   22.3
# 1980  24.7   22.0

# %%
recent.plot(color = ['skyblue', 'cornflowerblue'], xlabel = 'Year', ylabel = 'Median Age', 
            title = 'US Estimated Median Age at First Marriage:\n1980 to 2021');
plt.savefig("med_age_vis.jpg")

# %%
# practice for stats 21 final
plt.figure(figsize = (6,6)) # makes the actual graph a square box or wtvr size want
recent['Men'].plot()
plt.ylim(22,32);

# %%
import numpy as np
np.random.seed(1)
x = np.random.randint(0,101,100)
y = np.random.randint(0,51,100)
plt.figure(figsize = (5,5))
plt.scatter(x,y)
# plt.xlim(0,10)
plt.axis('equal') # makes things circular or square or rectangle for ex # overrides xlim using it after
plt.show()
